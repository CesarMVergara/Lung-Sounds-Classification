# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print('GPU device found:')
    for device in physical_devices:
        print(device)
else:
    print('No GPU devices found.')
# Out:
# GPU device found:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
SEED = 42
import os
os.environ['PYTHONHASHSEED'] = str(SEED)
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, applications, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def reset_seeds():
    np.random.seed(SEED)
    tf.random.set_seed(SEED)
    random.seed(SEED)

reset_seeds()

policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

train_loc = './OfficialSpectrogramsMelAUG/train'
test_loc = './OfficialSpectrogramsMelAUG/test'

# Definir la normalización
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Crear los generadores de datos
train_generator = train_datagen.flow_from_directory(
    directory=train_loc,
    target_size=(224,224),
    shuffle=True,
    seed=SEED
)

test_generator = test_datagen.flow_from_directory(
    directory=test_loc,
    target_size=(224,224),
    shuffle=False,
    seed=SEED
)

# Aplicar prefetch
train_dataset = tf.data.Dataset.from_generator(
    lambda: train_generator,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, 224, 224, 3], [None, len(train_generator.class_indices)])
)

test_dataset = tf.data.Dataset.from_generator(
    lambda: test_generator,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, 224, 224, 3], [None, len(test_generator.class_indices)])
)

class_names = list(train_generator.class_indices.keys())
print("Class names:", class_names)

# Cargar el modelo ResNet152V2 preentrenado
resnet152v2 = applications.ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Congelar todas las capas del modelo base
for layer in resnet152v2.layers:
    layer.trainable = False

# Descongelar la mitad de la cuarta etapa (bottleneck layers)
# Aquí identificamos las etapas específicas en ResNet152V2
# Etapas en ResNet152V2: 
# Conv1 -> Conv2_x -> Conv3_x -> Conv4_x -> Conv5_x

conv4_layers = [layer for layer in resnet152v2.layers if 'conv4' in layer.name]
half_conv4_index = len(conv4_layers) // 2

for layer in conv4_layers[half_conv4_index:]:
    layer.trainable = True

    # Imprimir las capas que se descongelan (son entrenables)
    print(f"Layer '{layer.name}' is trainable")

# Agregar nuevas capas de clasificación
x = layers.GlobalAveragePooling2D()(resnet152v2.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.5)(x)
prediction = layers.Dense(len(class_names), activation='softmax')(x)

# Crear el nuevo modelo
model = models.Model(inputs=resnet152v2.input, outputs=prediction)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

model.summary()
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4090, compute capability 8.9
# Found 8544 images belonging to 4 classes.
# Found 2756 images belonging to 4 classes.
# Class names: ['crackle', 'crackle_wheeze', 'normal', 'wheeze']
# Layer 'conv4_block18_out' is trainable
# Layer 'conv4_block19_preact_bn' is trainable
# Layer 'conv4_block19_preact_relu' is trainable
# Layer 'conv4_block19_1_conv' is trainable
# Layer 'conv4_block19_1_bn' is trainable
# Layer 'conv4_block19_1_relu' is trainable
# Layer 'conv4_block19_2_pad' is trainable
# Layer 'conv4_block19_2_conv' is trainable
# Layer 'conv4_block19_2_bn' is trainable
# Layer 'conv4_block19_2_relu' is trainable
# Layer 'conv4_block19_3_conv' is trainable
# Layer 'conv4_block19_out' is trainable
# Layer 'conv4_block20_preact_bn' is trainable
# Layer 'conv4_block20_preact_relu' is trainable
# Layer 'conv4_block20_1_conv' is trainable
# Layer 'conv4_block20_1_bn' is trainable
# Layer 'conv4_block20_1_relu' is trainable
# Layer 'conv4_block20_2_pad' is trainable
# Layer 'conv4_block20_2_conv' is trainable
# Layer 'conv4_block20_2_bn' is trainable
# Layer 'conv4_block20_2_relu' is trainable
# Layer 'conv4_block20_3_conv' is trainable
# Layer 'conv4_block20_out' is trainable
# Layer 'conv4_block21_preact_bn' is trainable
# Layer 'conv4_block21_preact_relu' is trainable
# Layer 'conv4_block21_1_conv' is trainable
# Layer 'conv4_block21_1_bn' is trainable
# Layer 'conv4_block21_1_relu' is trainable
# Layer 'conv4_block21_2_pad' is trainable
# Layer 'conv4_block21_2_conv' is trainable
# Layer 'conv4_block21_2_bn' is trainable
# Layer 'conv4_block21_2_relu' is trainable
# Layer 'conv4_block21_3_conv' is trainable
# Layer 'conv4_block21_out' is trainable
# Layer 'conv4_block22_preact_bn' is trainable
# Layer 'conv4_block22_preact_relu' is trainable
# Layer 'conv4_block22_1_conv' is trainable
# Layer 'conv4_block22_1_bn' is trainable
# Layer 'conv4_block22_1_relu' is trainable
# Layer 'conv4_block22_2_pad' is trainable
# Layer 'conv4_block22_2_conv' is trainable
# Layer 'conv4_block22_2_bn' is trainable
# Layer 'conv4_block22_2_relu' is trainable
# Layer 'conv4_block22_3_conv' is trainable
# Layer 'conv4_block22_out' is trainable
# Layer 'conv4_block23_preact_bn' is trainable
# Layer 'conv4_block23_preact_relu' is trainable
# Layer 'conv4_block23_1_conv' is trainable
# Layer 'conv4_block23_1_bn' is trainable
# Layer 'conv4_block23_1_relu' is trainable
# Layer 'conv4_block23_2_pad' is trainable
# Layer 'conv4_block23_2_conv' is trainable
# Layer 'conv4_block23_2_bn' is trainable
# Layer 'conv4_block23_2_relu' is trainable
# Layer 'conv4_block23_3_conv' is trainable
# Layer 'conv4_block23_out' is trainable
# Layer 'conv4_block24_preact_bn' is trainable
# Layer 'conv4_block24_preact_relu' is trainable
# Layer 'conv4_block24_1_conv' is trainable
# Layer 'conv4_block24_1_bn' is trainable
# Layer 'conv4_block24_1_relu' is trainable
# Layer 'conv4_block24_2_pad' is trainable
# Layer 'conv4_block24_2_conv' is trainable
# Layer 'conv4_block24_2_bn' is trainable
# Layer 'conv4_block24_2_relu' is trainable
# Layer 'conv4_block24_3_conv' is trainable
# Layer 'conv4_block24_out' is trainable
# Layer 'conv4_block25_preact_bn' is trainable
# Layer 'conv4_block25_preact_relu' is trainable
# Layer 'conv4_block25_1_conv' is trainable
# Layer 'conv4_block25_1_bn' is trainable
# Layer 'conv4_block25_1_relu' is trainable
# Layer 'conv4_block25_2_pad' is trainable
# Layer 'conv4_block25_2_conv' is trainable
# Layer 'conv4_block25_2_bn' is trainable
# Layer 'conv4_block25_2_relu' is trainable
# Layer 'conv4_block25_3_conv' is trainable
# Layer 'conv4_block25_out' is trainable
# Layer 'conv4_block26_preact_bn' is trainable
# Layer 'conv4_block26_preact_relu' is trainable
# Layer 'conv4_block26_1_conv' is trainable
# Layer 'conv4_block26_1_bn' is trainable
# Layer 'conv4_block26_1_relu' is trainable
# Layer 'conv4_block26_2_pad' is trainable
# Layer 'conv4_block26_2_conv' is trainable
# Layer 'conv4_block26_2_bn' is trainable
# Layer 'conv4_block26_2_relu' is trainable
# Layer 'conv4_block26_3_conv' is trainable
# Layer 'conv4_block26_out' is trainable
# Layer 'conv4_block27_preact_bn' is trainable
# Layer 'conv4_block27_preact_relu' is trainable
# Layer 'conv4_block27_1_conv' is trainable
# Layer 'conv4_block27_1_bn' is trainable
# Layer 'conv4_block27_1_relu' is trainable
# Layer 'conv4_block27_2_pad' is trainable
# Layer 'conv4_block27_2_conv' is trainable
# Layer 'conv4_block27_2_bn' is trainable
# Layer 'conv4_block27_2_relu' is trainable
# Layer 'conv4_block27_3_conv' is trainable
# Layer 'conv4_block27_out' is trainable
# Layer 'conv4_block28_preact_bn' is trainable
# Layer 'conv4_block28_preact_relu' is trainable
# Layer 'conv4_block28_1_conv' is trainable
# Layer 'conv4_block28_1_bn' is trainable
# Layer 'conv4_block28_1_relu' is trainable
# Layer 'conv4_block28_2_pad' is trainable
# Layer 'conv4_block28_2_conv' is trainable
# Layer 'conv4_block28_2_bn' is trainable
# Layer 'conv4_block28_2_relu' is trainable
# Layer 'conv4_block28_3_conv' is trainable
# Layer 'conv4_block28_out' is trainable
# Layer 'conv4_block29_preact_bn' is trainable
# Layer 'conv4_block29_preact_relu' is trainable
# Layer 'conv4_block29_1_conv' is trainable
# Layer 'conv4_block29_1_bn' is trainable
# Layer 'conv4_block29_1_relu' is trainable
# Layer 'conv4_block29_2_pad' is trainable
# Layer 'conv4_block29_2_conv' is trainable
# Layer 'conv4_block29_2_bn' is trainable
# Layer 'conv4_block29_2_relu' is trainable
# Layer 'conv4_block29_3_conv' is trainable
# Layer 'conv4_block29_out' is trainable
# Layer 'conv4_block30_preact_bn' is trainable
# Layer 'conv4_block30_preact_relu' is trainable
# Layer 'conv4_block30_1_conv' is trainable
# Layer 'conv4_block30_1_bn' is trainable
# Layer 'conv4_block30_1_relu' is trainable
# Layer 'conv4_block30_2_pad' is trainable
# Layer 'conv4_block30_2_conv' is trainable
# Layer 'conv4_block30_2_bn' is trainable
# Layer 'conv4_block30_2_relu' is trainable
# Layer 'conv4_block30_3_conv' is trainable
# Layer 'conv4_block30_out' is trainable
# Layer 'conv4_block31_preact_bn' is trainable
# Layer 'conv4_block31_preact_relu' is trainable
# Layer 'conv4_block31_1_conv' is trainable
# Layer 'conv4_block31_1_bn' is trainable
# Layer 'conv4_block31_1_relu' is trainable
# Layer 'conv4_block31_2_pad' is trainable
# Layer 'conv4_block31_2_conv' is trainable
# Layer 'conv4_block31_2_bn' is trainable
# Layer 'conv4_block31_2_relu' is trainable
# Layer 'conv4_block31_3_conv' is trainable
# Layer 'conv4_block31_out' is trainable
# Layer 'conv4_block32_preact_bn' is trainable
# Layer 'conv4_block32_preact_relu' is trainable
# Layer 'conv4_block32_1_conv' is trainable
# Layer 'conv4_block32_1_bn' is trainable
# Layer 'conv4_block32_1_relu' is trainable
# Layer 'conv4_block32_2_pad' is trainable
# Layer 'conv4_block32_2_conv' is trainable
# Layer 'conv4_block32_2_bn' is trainable
# Layer 'conv4_block32_2_relu' is trainable
# Layer 'conv4_block32_3_conv' is trainable
# Layer 'conv4_block32_out' is trainable
# Layer 'conv4_block33_preact_bn' is trainable
# Layer 'conv4_block33_preact_relu' is trainable
# Layer 'conv4_block33_1_conv' is trainable
# Layer 'conv4_block33_1_bn' is trainable
# Layer 'conv4_block33_1_relu' is trainable
# Layer 'conv4_block33_2_pad' is trainable
# Layer 'conv4_block33_2_conv' is trainable
# Layer 'conv4_block33_2_bn' is trainable
# Layer 'conv4_block33_2_relu' is trainable
# Layer 'conv4_block33_3_conv' is trainable
# Layer 'conv4_block33_out' is trainable
# Layer 'conv4_block34_preact_bn' is trainable
# Layer 'conv4_block34_preact_relu' is trainable
# Layer 'conv4_block34_1_conv' is trainable
# Layer 'conv4_block34_1_bn' is trainable
# Layer 'conv4_block34_1_relu' is trainable
# Layer 'conv4_block34_2_pad' is trainable
# Layer 'conv4_block34_2_conv' is trainable
# Layer 'conv4_block34_2_bn' is trainable
# Layer 'conv4_block34_2_relu' is trainable
# Layer 'conv4_block34_3_conv' is trainable
# Layer 'conv4_block34_out' is trainable
# Layer 'conv4_block35_preact_bn' is trainable
# Layer 'conv4_block35_preact_relu' is trainable
# Layer 'conv4_block35_1_conv' is trainable
# Layer 'conv4_block35_1_bn' is trainable
# Layer 'conv4_block35_1_relu' is trainable
# Layer 'conv4_block35_2_pad' is trainable
# Layer 'conv4_block35_2_conv' is trainable
# Layer 'conv4_block35_2_bn' is trainable
# Layer 'conv4_block35_2_relu' is trainable
# Layer 'conv4_block35_3_conv' is trainable
# Layer 'conv4_block35_out' is trainable
# Layer 'conv4_block36_preact_bn' is trainable
# Layer 'conv4_block36_preact_relu' is trainable
# Layer 'conv4_block36_1_conv' is trainable
# Layer 'conv4_block36_1_bn' is trainable
# Layer 'conv4_block36_1_relu' is trainable
# Layer 'conv4_block36_2_pad' is trainable
# Layer 'conv4_block36_2_conv' is trainable
# Layer 'conv4_block36_2_bn' is trainable
# Layer 'conv4_block36_2_relu' is trainable
# Layer 'conv4_block36_3_conv' is trainable
# Layer 'conv4_block36_out' is trainable
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv3_block5_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block5_preact_bn[0][0]']
#  vation)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block5_1_relu[0][0]']
#  g2D)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block5_2_pad[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_out (Add)         (None, 28, 28, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block5_out[0][0]']
#  ormalization)
#
#  conv3_block6_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block6_preact_bn[0][0]']
#  vation)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block6_1_relu[0][0]']
#  g2D)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block6_2_pad[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_out (Add)         (None, 28, 28, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block6_out[0][0]']
#  ormalization)
#
#  conv3_block7_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block7_preact_bn[0][0]']
#  vation)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block7_1_relu[0][0]']
#  g2D)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block7_2_pad[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_out (Add)         (None, 28, 28, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block7_out[0][0]']
#  ormalization)
#
#  conv3_block8_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block8_preact_bn[0][0]']
#  vation)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block8_1_relu[0][0]']
#  g2D)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block8_2_pad[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block7_out[0][0]']
#
#  conv3_block8_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block8_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
# ...
#
#  conv4_block35_2_conv (Conv2D)  (None, 14, 14, 256)  589824      ['conv4_block35_2_pad[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_out (Add)        (None, 14, 14, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_conv[0][0]']
#
#  conv4_block36_preact_bn (Batch  (None, 14, 14, 1024  4096       ['conv4_block35_out[0][0]']
#  Normalization)                 )
#
#  conv4_block36_preact_relu (Act  (None, 14, 14, 1024  0          ['conv4_block36_preact_bn[0][0]']
#  ivation)                       )
#
#  conv4_block36_1_conv (Conv2D)  (None, 14, 14, 256)  262144      ['conv4_block36_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block36_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block36_1_relu[0][0]']
#  ng2D)
#
#  conv4_block36_2_conv (Conv2D)  (None, 7, 7, 256)    589824      ['conv4_block36_2_pad[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 7, 7, 256)   1024        ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 7, 7, 256)   0           ['conv4_block36_2_bn[0][0]']
#  on)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block35_out[0][0]']
#
#  conv4_block36_3_conv (Conv2D)  (None, 7, 7, 1024)   263168      ['conv4_block36_2_relu[0][0]']
#
#  conv4_block36_out (Add)        (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block36_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['post_relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1024)         2098176     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 4)            4100        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 60,433,924
# Trainable params: 22,230,020
# Non-trainable params: 38,203,904
# __________________________________________________________________________________________________

# %%
# Callback personalizado para monitorear dos métricas y una condición adicional
class CustomModelCheckpoint(callbacks.Callback):
    def __init__(self, filepath, monitor1='val_accuracy', monitor2='val_loss', mode1='max', mode2='min', save_best_only=True, ignore_initial_epochs=15, verbose=0, loss_threshold=3):
        super().__init__()
        self.filepath = filepath
        self.monitor1 = monitor1
        self.monitor2 = monitor2
        self.mode1 = mode1
        self.mode2 = mode2
        self.save_best_only = save_best_only
        self.ignore_initial_epochs = ignore_initial_epochs
        self.verbose = verbose
        self.loss_threshold = loss_threshold
        self.best = None  # Guardamos la mejor métrica principal
        self.best_epoch = -1

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.ignore_initial_epochs:
            return
        
        current1 = logs.get(self.monitor1)
        current2 = logs.get(self.monitor2)

        if current2 < self.loss_threshold and (self.best is None or self._compare(current1, self.best, self.mode1)):
            self.best = current1
            self.best_epoch = epoch
            if self.verbose > 0:
                print(f"\nEpoch {epoch + 1}: {self.monitor1} improved to {current1}, {self.monitor2} is {current2}, saving model to {self.filepath}")
            if self.save_best_only:
                self.model.save(self.filepath, overwrite=True)
            else:
                self.model.save(self.filepath.format(epoch=epoch, **logs))
        else:
            if self.verbose > 0:
                print(f"\nEpoch {epoch + 1}: {self.monitor1} did not improve from {self.best}, {self.monitor2} is {current2}")

    def _compare(self, current, best, mode):
        if best is None:
            return True
        if mode == 'max':
            return current > best
        else:  # mode == 'min'
            return current < best


# Callback personalizado para EarlyStopping
class CustomEarlyStopping(callbacks.EarlyStopping):
    def __init__(self, *args, ignore_initial_epochs=3, **kwargs):
        super().__init__(*args, **kwargs)
        self.ignore_initial_epochs = ignore_initial_epochs
        self.wait = 0  # To track the number of epochs since the best score was improved

    def on_epoch_end(self, epoch, logs=None):
        if epoch >= self.ignore_initial_epochs:
            super().on_epoch_end(epoch, logs)

# %%
# Ruta para guardar el modelo
checkpoint_path = './Best_Models/Tests/RN152V2_Adam_00005.h5'

# Callback para guardar el mejor modelo basado en la precisión en el conjunto de validación
checkpoint_callback = CustomModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    ignore_initial_epochs=5
)
early = CustomEarlyStopping(monitor='val_accuracy', min_delta=0, patience=60, verbose=1, mode='max', ignore_initial_epochs=5)

# %%
from collections import Counter

counter = Counter(train_generator.classes)                       
max_val = float(max(counter.values()))   
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}
class_weights
# Out:
# {0: 1.0, 1: 1.564657393096342, 2: 1.4721279689772175, 3: 2.0206254158349966}

# %%
# Train the model
history = model.fit(train_dataset, validation_data=test_dataset, 
                    steps_per_epoch=train_generator.samples//train_generator.batch_size, 
                    validation_steps=test_generator.samples//test_generator.batch_size,
                    epochs=250, callbacks=[checkpoint_callback, early], verbose=2, class_weight=class_weights)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print("Validation loss:", loss)
print("Validation accuracy:", accuracy)
# Out:
# Epoch 1/250
# 267/267 - 51s - loss: 1.7209 - accuracy: 0.4441 - val_loss: 1.1173 - val_accuracy: 0.5338 - 51s/epoch - 193ms/step
# Epoch 2/250
# 267/267 - 21s - loss: 1.2653 - accuracy: 0.6188 - val_loss: 1.2898 - val_accuracy: 0.4728 - 21s/epoch - 78ms/step
# Epoch 3/250
# 267/267 - 21s - loss: 0.9625 - accuracy: 0.7231 - val_loss: 1.4160 - val_accuracy: 0.4912 - 21s/epoch - 79ms/step
# Epoch 4/250
# 267/267 - 21s - loss: 0.7112 - accuracy: 0.8074 - val_loss: 1.5361 - val_accuracy: 0.4824 - 21s/epoch - 77ms/step
# Epoch 5/250
# 267/267 - 21s - loss: 0.5565 - accuracy: 0.8540 - val_loss: 1.5952 - val_accuracy: 0.5235 - 21s/epoch - 79ms/step
# Epoch 6/250
#
# Epoch 6: val_accuracy improved to 0.5334067344665527, val_loss is 1.4317610263824463, saving model to ./Best_Models/Tests/RN152V2_Adam_00005.h5
# 267/267 - 22s - loss: 0.4625 - accuracy: 0.8755 - val_loss: 1.4318 - val_accuracy: 0.5334 - 22s/epoch - 82ms/step
# Epoch 7/250
#
# Epoch 7: val_accuracy improved to 0.5396475791931152, val_loss is 1.5996767282485962, saving model to ./Best_Models/Tests/RN152V2_Adam_00005.h5
# 267/267 - 22s - loss: 0.3905 - accuracy: 0.8913 - val_loss: 1.5997 - val_accuracy: 0.5396 - 22s/epoch - 82ms/step
# Epoch 8/250
#
# Epoch 8: val_accuracy improved to 0.5554332137107849, val_loss is 1.603380799293518, saving model to ./Best_Models/Tests/RN152V2_Adam_00005.h5
# 267/267 - 21s - loss: 0.3415 - accuracy: 0.8968 - val_loss: 1.6034 - val_accuracy: 0.5554 - 21s/epoch - 80ms/step
# Epoch 9/250
#
# Epoch 9: val_accuracy did not improve from 0.5554332137107849, val_loss is 1.8031903505325317
# 267/267 - 21s - loss: 0.3093 - accuracy: 0.9033 - val_loss: 1.8032 - val_accuracy: 0.4684 - 21s/epoch - 79ms/step
# Epoch 10/250
#
# Epoch 10: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.1474452018737793
# 267/267 - 21s - loss: 0.2991 - accuracy: 0.9077 - val_loss: 2.1474 - val_accuracy: 0.4589 - 21s/epoch - 80ms/step
# Epoch 11/250
#
# Epoch 11: val_accuracy did not improve from 0.5554332137107849, val_loss is 1.9483898878097534
# 267/267 - 21s - loss: 0.2857 - accuracy: 0.9060 - val_loss: 1.9484 - val_accuracy: 0.5257 - 21s/epoch - 79ms/step
# Epoch 12/250
#
# Epoch 12: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.049978256225586
# 267/267 - 21s - loss: 0.2757 - accuracy: 0.9091 - val_loss: 2.0500 - val_accuracy: 0.4703 - 21s/epoch - 78ms/step
# Epoch 13/250
#
# Epoch 13: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.3297712802886963
# 267/267 - 21s - loss: 0.2640 - accuracy: 0.9110 - val_loss: 2.3298 - val_accuracy: 0.4890 - 21s/epoch - 78ms/step
# Epoch 14/250
#
# Epoch 14: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.3626444339752197
# 267/267 - 21s - loss: 0.2640 - accuracy: 0.9128 - val_loss: 2.3626 - val_accuracy: 0.5272 - 21s/epoch - 78ms/step
# Epoch 15/250
#
# Epoch 15: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.4009385108947754
# 267/267 - 21s - loss: 0.2835 - accuracy: 0.9023 - val_loss: 2.4009 - val_accuracy: 0.4600 - 21s/epoch - 78ms/step
# Epoch 16/250
#
# Epoch 16: val_accuracy did not improve from 0.5554332137107849, val_loss is 1.938714623451233
# 267/267 - 21s - loss: 0.2521 - accuracy: 0.9143 - val_loss: 1.9387 - val_accuracy: 0.5330 - 21s/epoch - 79ms/step
# Epoch 17/250
#
# Epoch 17: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.318617582321167
# 267/267 - 21s - loss: 0.2533 - accuracy: 0.9137 - val_loss: 2.3186 - val_accuracy: 0.5151 - 21s/epoch - 79ms/step
# Epoch 18/250
#
# Epoch 18: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.0272719860076904
# 267/267 - 21s - loss: 0.2366 - accuracy: 0.9129 - val_loss: 2.0273 - val_accuracy: 0.5312 - 21s/epoch - 79ms/step
# Epoch 19/250
#
# Epoch 19: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.3048064708709717
# 267/267 - 21s - loss: 0.2258 - accuracy: 0.9217 - val_loss: 2.3048 - val_accuracy: 0.5209 - 21s/epoch - 79ms/step
# Epoch 20/250
#
# Epoch 20: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.4368460178375244
# 267/267 - 21s - loss: 0.2255 - accuracy: 0.9171 - val_loss: 2.4368 - val_accuracy: 0.5239 - 21s/epoch - 78ms/step
# Epoch 21/250
#
# Epoch 21: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.6296920776367188
# 267/267 - 21s - loss: 0.2176 - accuracy: 0.9218 - val_loss: 2.6297 - val_accuracy: 0.5070 - 21s/epoch - 79ms/step
# Epoch 22/250
#
# Epoch 22: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.212205171585083
# 267/267 - 21s - loss: 0.2205 - accuracy: 0.9182 - val_loss: 2.2122 - val_accuracy: 0.5385 - 21s/epoch - 78ms/step
# Epoch 23/250
#
# Epoch 23: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.5866775512695312
# 267/267 - 21s - loss: 0.2238 - accuracy: 0.9177 - val_loss: 2.5867 - val_accuracy: 0.5029 - 21s/epoch - 78ms/step
# Epoch 24/250
#
# Epoch 24: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.1223928928375244
# 267/267 - 21s - loss: 0.2153 - accuracy: 0.9198 - val_loss: 2.1224 - val_accuracy: 0.5404 - 21s/epoch - 77ms/step
# Epoch 25/250
#
# Epoch 25: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.8392672538757324
# 267/267 - 21s - loss: 0.2222 - accuracy: 0.9219 - val_loss: 2.8393 - val_accuracy: 0.5070 - 21s/epoch - 78ms/step
# Epoch 26/250
#
# Epoch 26: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.8006277084350586
# 267/267 - 21s - loss: 0.2058 - accuracy: 0.9232 - val_loss: 2.8006 - val_accuracy: 0.5507 - 21s/epoch - 78ms/step
# Epoch 27/250
#
# Epoch 27: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.401684045791626
# 267/267 - 21s - loss: 0.2208 - accuracy: 0.9217 - val_loss: 2.4017 - val_accuracy: 0.5250 - 21s/epoch - 79ms/step
# Epoch 28/250
#
# Epoch 28: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.660993814468384
# 267/267 - 21s - loss: 0.1966 - accuracy: 0.9246 - val_loss: 2.6610 - val_accuracy: 0.5187 - 21s/epoch - 79ms/step
# Epoch 29/250
#
# Epoch 29: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.6784369945526123
# 267/267 - 21s - loss: 0.1678 - accuracy: 0.9307 - val_loss: 2.6784 - val_accuracy: 0.5345 - 21s/epoch - 80ms/step
# Epoch 30/250
#
# Epoch 30: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.855703830718994
# 267/267 - 21s - loss: 0.1750 - accuracy: 0.9292 - val_loss: 2.8557 - val_accuracy: 0.5363 - 21s/epoch - 78ms/step
# Epoch 31/250
#
# Epoch 31: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.673945665359497
# 267/267 - 21s - loss: 0.2309 - accuracy: 0.9178 - val_loss: 2.6739 - val_accuracy: 0.4791 - 21s/epoch - 79ms/step
# Epoch 32/250
#
# Epoch 32: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.5039291381835938
# 267/267 - 21s - loss: 0.2129 - accuracy: 0.9232 - val_loss: 2.5039 - val_accuracy: 0.4941 - 21s/epoch - 77ms/step
# Epoch 33/250
#
# Epoch 33: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.2041690349578857
# 267/267 - 21s - loss: 0.1906 - accuracy: 0.9287 - val_loss: 3.2042 - val_accuracy: 0.4732 - 21s/epoch - 77ms/step
# Epoch 34/250
#
# Epoch 34: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.910116195678711
# 267/267 - 21s - loss: 0.2320 - accuracy: 0.9196 - val_loss: 2.9101 - val_accuracy: 0.5033 - 21s/epoch - 78ms/step
# Epoch 35/250
#
# Epoch 35: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.847954511642456
# 267/267 - 21s - loss: 0.1906 - accuracy: 0.9259 - val_loss: 2.8480 - val_accuracy: 0.4666 - 21s/epoch - 78ms/step
# Epoch 36/250
#
# Epoch 36: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.3111119270324707
# 267/267 - 21s - loss: 0.1816 - accuracy: 0.9301 - val_loss: 3.3111 - val_accuracy: 0.4526 - 21s/epoch - 79ms/step
# Epoch 37/250
#
# Epoch 37: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.8427376747131348
# 267/267 - 21s - loss: 0.1731 - accuracy: 0.9321 - val_loss: 2.8427 - val_accuracy: 0.5136 - 21s/epoch - 78ms/step
# Epoch 38/250
#
# Epoch 38: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.1960294246673584
# 267/267 - 21s - loss: 0.1786 - accuracy: 0.9284 - val_loss: 3.1960 - val_accuracy: 0.4776 - 21s/epoch - 78ms/step
# Epoch 39/250
#
# Epoch 39: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.2986130714416504
# 267/267 - 21s - loss: 0.1759 - accuracy: 0.9313 - val_loss: 3.2986 - val_accuracy: 0.4838 - 21s/epoch - 78ms/step
# Epoch 40/250
#
# Epoch 40: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.593985080718994
# 267/267 - 21s - loss: 0.1797 - accuracy: 0.9301 - val_loss: 2.5940 - val_accuracy: 0.5452 - 21s/epoch - 78ms/step
# Epoch 41/250
#
# Epoch 41: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.5603203773498535
# 267/267 - 21s - loss: 0.1920 - accuracy: 0.9264 - val_loss: 2.5603 - val_accuracy: 0.5143 - 21s/epoch - 79ms/step
# Epoch 42/250
#
# Epoch 42: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.498305082321167
# 267/267 - 21s - loss: 0.1985 - accuracy: 0.9238 - val_loss: 2.4983 - val_accuracy: 0.5448 - 21s/epoch - 78ms/step
# Epoch 43/250
#
# Epoch 43: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.591564655303955
# 267/267 - 21s - loss: 0.1808 - accuracy: 0.9315 - val_loss: 2.5916 - val_accuracy: 0.5312 - 21s/epoch - 77ms/step
# Epoch 44/250
#
# Epoch 44: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.7562122344970703
# 267/267 - 21s - loss: 0.1722 - accuracy: 0.9314 - val_loss: 2.7562 - val_accuracy: 0.4710 - 21s/epoch - 79ms/step
# Epoch 45/250
#
# Epoch 45: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.8500969409942627
# 267/267 - 21s - loss: 0.1805 - accuracy: 0.9301 - val_loss: 2.8501 - val_accuracy: 0.5250 - 21s/epoch - 78ms/step
# Epoch 46/250
#
# Epoch 46: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.764770269393921
# 267/267 - 21s - loss: 0.1896 - accuracy: 0.9276 - val_loss: 2.7648 - val_accuracy: 0.4996 - 21s/epoch - 79ms/step
# Epoch 47/250
#
# Epoch 47: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.9211466312408447
# 267/267 - 21s - loss: 0.1758 - accuracy: 0.9306 - val_loss: 2.9211 - val_accuracy: 0.5184 - 21s/epoch - 80ms/step
# Epoch 48/250
#
# Epoch 48: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.9353718757629395
# 267/267 - 21s - loss: 0.1762 - accuracy: 0.9309 - val_loss: 2.9354 - val_accuracy: 0.5485 - 21s/epoch - 79ms/step
# Epoch 49/250
#
# Epoch 49: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.3967854976654053
# 267/267 - 21s - loss: 0.1841 - accuracy: 0.9315 - val_loss: 3.3968 - val_accuracy: 0.4938 - 21s/epoch - 79ms/step
# Epoch 50/250
#
# Epoch 50: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.6154093742370605
# 267/267 - 21s - loss: 0.1828 - accuracy: 0.9291 - val_loss: 2.6154 - val_accuracy: 0.5048 - 21s/epoch - 78ms/step
# Epoch 51/250
#
# Epoch 51: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.587176561355591
# 267/267 - 21s - loss: 0.1626 - accuracy: 0.9325 - val_loss: 2.5872 - val_accuracy: 0.5018 - 21s/epoch - 78ms/step
# Epoch 52/250
#
# Epoch 52: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.95477557182312
# 267/267 - 21s - loss: 0.1808 - accuracy: 0.9281 - val_loss: 2.9548 - val_accuracy: 0.5470 - 21s/epoch - 78ms/step
# Epoch 53/250
#
# Epoch 53: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.026167869567871
# 267/267 - 21s - loss: 0.2019 - accuracy: 0.9252 - val_loss: 3.0262 - val_accuracy: 0.5195 - 21s/epoch - 78ms/step
# Epoch 54/250
#
# Epoch 54: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.6741693019866943
# 267/267 - 21s - loss: 0.1710 - accuracy: 0.9336 - val_loss: 2.6742 - val_accuracy: 0.4908 - 21s/epoch - 79ms/step
# Epoch 55/250
#
# Epoch 55: val_accuracy did not improve from 0.5554332137107849, val_loss is 3.2444474697113037
# 267/267 - 21s - loss: 0.1666 - accuracy: 0.9318 - val_loss: 3.2444 - val_accuracy: 0.4802 - 21s/epoch - 78ms/step
# Epoch 56/250
#
# Epoch 56: val_accuracy did not improve from 0.5554332137107849, val_loss is 2.4642386436462402
# 267/267 - 21s - loss: 0.1539 - accuracy: 0.9383 - val_loss: 2.4642 - val_accuracy: 0.5349 - 21s/epoch - 79ms/step
# Epoch 57/250
#
# Epoch 57: val_accuracy improved to 0.5657122135162354, val_loss is 2.743638753890991, saving model to ./Best_Models/Tests/RN152V2_Adam_00005.h5
# 267/267 - 22s - loss: 0.1579 - accuracy: 0.9355 - val_loss: 2.7436 - val_accuracy: 0.5657 - 22s/epoch - 81ms/step
# Epoch 58/250
#
# Epoch 58: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.1920313835144043
# 267/267 - 21s - loss: 0.1675 - accuracy: 0.9349 - val_loss: 3.1920 - val_accuracy: 0.5360 - 21s/epoch - 80ms/step
# Epoch 59/250
#
# Epoch 59: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.98199462890625
# 267/267 - 20s - loss: 0.1579 - accuracy: 0.9348 - val_loss: 2.9820 - val_accuracy: 0.5202 - 20s/epoch - 76ms/step
# Epoch 60/250
#
# Epoch 60: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.857487916946411
# 267/267 - 21s - loss: 0.1725 - accuracy: 0.9375 - val_loss: 2.8575 - val_accuracy: 0.5187 - 21s/epoch - 78ms/step
# Epoch 61/250
#
# Epoch 61: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.348533868789673
# 267/267 - 21s - loss: 0.1672 - accuracy: 0.9355 - val_loss: 3.3485 - val_accuracy: 0.5323 - 21s/epoch - 78ms/step
# Epoch 62/250
#
# Epoch 62: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.0720906257629395
# 267/267 - 21s - loss: 0.1572 - accuracy: 0.9359 - val_loss: 3.0721 - val_accuracy: 0.4982 - 21s/epoch - 79ms/step
# Epoch 63/250
#
# Epoch 63: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.1023025512695312
# 267/267 - 21s - loss: 0.1713 - accuracy: 0.9301 - val_loss: 3.1023 - val_accuracy: 0.4908 - 21s/epoch - 79ms/step
# Epoch 64/250
#
# Epoch 64: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.689037322998047
# 267/267 - 21s - loss: 0.1639 - accuracy: 0.9350 - val_loss: 2.6890 - val_accuracy: 0.5011 - 21s/epoch - 77ms/step
# Epoch 65/250
#
# Epoch 65: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.111095905303955
# 267/267 - 21s - loss: 0.1508 - accuracy: 0.9353 - val_loss: 3.1111 - val_accuracy: 0.5151 - 21s/epoch - 78ms/step
# Epoch 66/250
#
# Epoch 66: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.0659990310668945
# 267/267 - 21s - loss: 0.1654 - accuracy: 0.9322 - val_loss: 3.0660 - val_accuracy: 0.5088 - 21s/epoch - 77ms/step
# Epoch 67/250
#
# Epoch 67: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.067751407623291
# 267/267 - 21s - loss: 0.1689 - accuracy: 0.9309 - val_loss: 3.0678 - val_accuracy: 0.5106 - 21s/epoch - 78ms/step
# Epoch 68/250
#
# Epoch 68: val_accuracy did not improve from 0.5657122135162354, val_loss is 4.065666198730469
# 267/267 - 21s - loss: 0.1934 - accuracy: 0.9290 - val_loss: 4.0657 - val_accuracy: 0.4203 - 21s/epoch - 80ms/step
# Epoch 69/250
#
# Epoch 69: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.9103798866271973
# 267/267 - 21s - loss: 0.1782 - accuracy: 0.9333 - val_loss: 2.9104 - val_accuracy: 0.5169 - 21s/epoch - 77ms/step
# Epoch 70/250
#
# Epoch 70: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.115065097808838
# 267/267 - 21s - loss: 0.1416 - accuracy: 0.9386 - val_loss: 3.1151 - val_accuracy: 0.5198 - 21s/epoch - 79ms/step
# Epoch 71/250
#
# Epoch 71: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.233703851699829
# 267/267 - 21s - loss: 0.1462 - accuracy: 0.9387 - val_loss: 3.2337 - val_accuracy: 0.5286 - 21s/epoch - 80ms/step
# Epoch 72/250
#
# Epoch 72: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.5829834938049316
# 267/267 - 21s - loss: 0.1572 - accuracy: 0.9362 - val_loss: 2.5830 - val_accuracy: 0.5202 - 21s/epoch - 78ms/step
# Epoch 73/250
#
# Epoch 73: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.8068041801452637
# 267/267 - 21s - loss: 0.1739 - accuracy: 0.9315 - val_loss: 2.8068 - val_accuracy: 0.5261 - 21s/epoch - 79ms/step
# Epoch 74/250
#
# Epoch 74: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.3880667686462402
# 267/267 - 21s - loss: 0.1604 - accuracy: 0.9357 - val_loss: 3.3881 - val_accuracy: 0.4651 - 21s/epoch - 78ms/step
# Epoch 75/250
#
# Epoch 75: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.35969614982605
# 267/267 - 21s - loss: 0.1676 - accuracy: 0.9334 - val_loss: 3.3597 - val_accuracy: 0.5510 - 21s/epoch - 77ms/step
# Epoch 76/250
#
# Epoch 76: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.594895839691162
# 267/267 - 21s - loss: 0.1490 - accuracy: 0.9382 - val_loss: 2.5949 - val_accuracy: 0.5488 - 21s/epoch - 77ms/step
# Epoch 77/250
#
# Epoch 77: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.811306953430176
# 267/267 - 21s - loss: 0.1842 - accuracy: 0.9302 - val_loss: 2.8113 - val_accuracy: 0.5099 - 21s/epoch - 79ms/step
# Epoch 78/250
#
# Epoch 78: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.020305633544922
# 267/267 - 21s - loss: 0.1659 - accuracy: 0.9356 - val_loss: 3.0203 - val_accuracy: 0.4927 - 21s/epoch - 79ms/step
# Epoch 79/250
#
# Epoch 79: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.4863767623901367
# 267/267 - 21s - loss: 0.1493 - accuracy: 0.9363 - val_loss: 3.4864 - val_accuracy: 0.4787 - 21s/epoch - 80ms/step
# Epoch 80/250
#
# Epoch 80: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.446528434753418
# 267/267 - 21s - loss: 0.1534 - accuracy: 0.9379 - val_loss: 3.4465 - val_accuracy: 0.5231 - 21s/epoch - 79ms/step
# Epoch 81/250
#
# Epoch 81: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.02677583694458
# 267/267 - 21s - loss: 0.1518 - accuracy: 0.9356 - val_loss: 3.0268 - val_accuracy: 0.5363 - 21s/epoch - 78ms/step
# Epoch 82/250
#
# Epoch 82: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.6688005924224854
# 267/267 - 21s - loss: 0.1433 - accuracy: 0.9383 - val_loss: 2.6688 - val_accuracy: 0.5059 - 21s/epoch - 79ms/step
# Epoch 83/250
#
# Epoch 83: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.392695665359497
# 267/267 - 21s - loss: 0.1383 - accuracy: 0.9391 - val_loss: 3.3927 - val_accuracy: 0.5261 - 21s/epoch - 78ms/step
# Epoch 84/250
#
# Epoch 84: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.130093574523926
# 267/267 - 21s - loss: 0.1532 - accuracy: 0.9388 - val_loss: 3.1301 - val_accuracy: 0.5022 - 21s/epoch - 78ms/step
# Epoch 85/250
#
# Epoch 85: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.5901706218719482
# 267/267 - 21s - loss: 0.1426 - accuracy: 0.9401 - val_loss: 3.5902 - val_accuracy: 0.5349 - 21s/epoch - 80ms/step
# Epoch 86/250
#
# Epoch 86: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.357550859451294
# 267/267 - 21s - loss: 0.1339 - accuracy: 0.9395 - val_loss: 3.3576 - val_accuracy: 0.5374 - 21s/epoch - 79ms/step
# Epoch 87/250
#
# Epoch 87: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.6383018493652344
# 267/267 - 21s - loss: 0.1427 - accuracy: 0.9387 - val_loss: 2.6383 - val_accuracy: 0.5239 - 21s/epoch - 77ms/step
# Epoch 88/250
#
# Epoch 88: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.2903597354888916
# 267/267 - 21s - loss: 0.1811 - accuracy: 0.9314 - val_loss: 3.2904 - val_accuracy: 0.4895 - 21s/epoch - 79ms/step
# Epoch 89/250
#
# Epoch 89: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.0434017181396484
# 267/267 - 21s - loss: 0.1751 - accuracy: 0.9350 - val_loss: 3.0434 - val_accuracy: 0.5430 - 21s/epoch - 78ms/step
# Epoch 90/250
#
# Epoch 90: val_accuracy did not improve from 0.5657122135162354, val_loss is 4.064708232879639
# 267/267 - 21s - loss: 0.1542 - accuracy: 0.9371 - val_loss: 4.0647 - val_accuracy: 0.4798 - 21s/epoch - 79ms/step
# Epoch 91/250
#
# Epoch 91: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.9885566234588623
# 267/267 - 21s - loss: 0.1658 - accuracy: 0.9371 - val_loss: 2.9886 - val_accuracy: 0.5114 - 21s/epoch - 78ms/step
# Epoch 92/250
#
# Epoch 92: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.3497211933135986
# 267/267 - 21s - loss: 0.1578 - accuracy: 0.9374 - val_loss: 3.3497 - val_accuracy: 0.5316 - 21s/epoch - 78ms/step
# Epoch 93/250
#
# Epoch 93: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.4996156692504883
# 267/267 - 21s - loss: 0.1316 - accuracy: 0.9401 - val_loss: 3.4996 - val_accuracy: 0.5004 - 21s/epoch - 79ms/step
# Epoch 94/250
#
# Epoch 94: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.23884916305542
# 267/267 - 21s - loss: 0.1262 - accuracy: 0.9408 - val_loss: 3.2388 - val_accuracy: 0.5202 - 21s/epoch - 78ms/step
# Epoch 95/250
#
# Epoch 95: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.735177993774414
# 267/267 - 21s - loss: 0.1264 - accuracy: 0.9435 - val_loss: 3.7352 - val_accuracy: 0.5048 - 21s/epoch - 79ms/step
# Epoch 96/250
#
# Epoch 96: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.537330150604248
# 267/267 - 21s - loss: 0.1257 - accuracy: 0.9476 - val_loss: 3.5373 - val_accuracy: 0.5066 - 21s/epoch - 80ms/step
# Epoch 97/250
#
# Epoch 97: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.4718058109283447
# 267/267 - 21s - loss: 0.1259 - accuracy: 0.9429 - val_loss: 3.4718 - val_accuracy: 0.5466 - 21s/epoch - 79ms/step
# Epoch 98/250
#
# Epoch 98: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.7849783897399902
# 267/267 - 20s - loss: 0.1609 - accuracy: 0.9357 - val_loss: 3.7850 - val_accuracy: 0.5250 - 20s/epoch - 76ms/step
# Epoch 99/250
#
# Epoch 99: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.7822136878967285
# 267/267 - 21s - loss: 0.1696 - accuracy: 0.9328 - val_loss: 3.7822 - val_accuracy: 0.4960 - 21s/epoch - 79ms/step
# Epoch 100/250
#
# Epoch 100: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.9914705753326416
# 267/267 - 21s - loss: 0.1560 - accuracy: 0.9369 - val_loss: 2.9915 - val_accuracy: 0.5404 - 21s/epoch - 78ms/step
# Epoch 101/250
#
# Epoch 101: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.356618881225586
# 267/267 - 21s - loss: 0.1521 - accuracy: 0.9377 - val_loss: 3.3566 - val_accuracy: 0.5301 - 21s/epoch - 80ms/step
# Epoch 102/250
#
# Epoch 102: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.211516857147217
# 267/267 - 21s - loss: 0.1414 - accuracy: 0.9404 - val_loss: 3.2115 - val_accuracy: 0.5404 - 21s/epoch - 78ms/step
# Epoch 103/250
#
# Epoch 103: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.629697799682617
# 267/267 - 21s - loss: 0.1503 - accuracy: 0.9391 - val_loss: 3.6297 - val_accuracy: 0.5173 - 21s/epoch - 78ms/step
# Epoch 104/250
#
# Epoch 104: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.5276591777801514
# 267/267 - 21s - loss: 0.1449 - accuracy: 0.9395 - val_loss: 3.5277 - val_accuracy: 0.4692 - 21s/epoch - 77ms/step
# Epoch 105/250
#
# Epoch 105: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.1958000659942627
# 267/267 - 21s - loss: 0.1463 - accuracy: 0.9408 - val_loss: 3.1958 - val_accuracy: 0.5158 - 21s/epoch - 79ms/step
# Epoch 106/250
#
# Epoch 106: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.291224956512451
# 267/267 - 21s - loss: 0.1488 - accuracy: 0.9379 - val_loss: 3.2912 - val_accuracy: 0.5180 - 21s/epoch - 80ms/step
# Epoch 107/250
#
# Epoch 107: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.406949758529663
# 267/267 - 21s - loss: 0.1553 - accuracy: 0.9361 - val_loss: 3.4069 - val_accuracy: 0.5308 - 21s/epoch - 78ms/step
# Epoch 108/250
#
# Epoch 108: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.7680342197418213
# 267/267 - 21s - loss: 0.1522 - accuracy: 0.9396 - val_loss: 3.7680 - val_accuracy: 0.4611 - 21s/epoch - 78ms/step
# Epoch 109/250
#
# Epoch 109: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.1966259479522705
# 267/267 - 21s - loss: 0.1473 - accuracy: 0.9401 - val_loss: 3.1966 - val_accuracy: 0.5374 - 21s/epoch - 78ms/step
# Epoch 110/250
#
# Epoch 110: val_accuracy did not improve from 0.5657122135162354, val_loss is 2.9750826358795166
# 267/267 - 21s - loss: 0.1446 - accuracy: 0.9386 - val_loss: 2.9751 - val_accuracy: 0.5499 - 21s/epoch - 78ms/step
# Epoch 111/250
#
# Epoch 111: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.3021750450134277
# 267/267 - 21s - loss: 0.1379 - accuracy: 0.9412 - val_loss: 3.3022 - val_accuracy: 0.4989 - 21s/epoch - 78ms/step
# Epoch 112/250
#
# Epoch 112: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.7746708393096924
# 267/267 - 21s - loss: 0.1252 - accuracy: 0.9436 - val_loss: 3.7747 - val_accuracy: 0.5444 - 21s/epoch - 79ms/step
# Epoch 113/250
#
# Epoch 113: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.349245071411133
# 267/267 - 21s - loss: 0.1245 - accuracy: 0.9437 - val_loss: 3.3492 - val_accuracy: 0.5128 - 21s/epoch - 78ms/step
# Epoch 114/250
#
# Epoch 114: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.7813074588775635
# 267/267 - 21s - loss: 0.1270 - accuracy: 0.9417 - val_loss: 3.7813 - val_accuracy: 0.5140 - 21s/epoch - 78ms/step
# Epoch 115/250
#
# Epoch 115: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.8729007244110107
# 267/267 - 21s - loss: 0.1259 - accuracy: 0.9423 - val_loss: 3.8729 - val_accuracy: 0.5044 - 21s/epoch - 78ms/step
# Epoch 116/250
#
# Epoch 116: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.2934906482696533
# 267/267 - 21s - loss: 0.1596 - accuracy: 0.9379 - val_loss: 3.2935 - val_accuracy: 0.4971 - 21s/epoch - 79ms/step
# Epoch 117/250
#
# Epoch 117: val_accuracy did not improve from 0.5657122135162354, val_loss is 3.1561007499694824
# 267/267 - 21s - loss: 0.1508 - accuracy: 0.9366 - val_loss: 3.1561 - val_accuracy: 0.5338 - 21s/epoch - 79ms/step
# Epoch 117: early stopping
# 87/87 [==============================] - 7s 63ms/step - loss: 3.1363 - accuracy: 0.5356
# Validation loss: 3.136270761489868
# Validation accuracy: 0.5355587601661682

# %%
import matplotlib.pyplot as plt

# Plotear el accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plotear el loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# Predicciones en el conjunto de prueba
predictions = model.predict(test_generator)

# Obtener las etiquetas verdaderas del conjunto de prueba
y_true = test_generator.classes

# Convertir las predicciones en etiquetas de clase
y_pred_classes = np.argmax(predictions, axis=1)

# Calcular métricas
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')

# Mostrar las métricas
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Obtener el número total de predicciones correctas para cada clase
Pc = sum((y_true == 0) & (y_pred_classes == 0))  # Crackle
Pb = sum((y_true == 1) & (y_pred_classes == 1))  # Both
Pn = sum((y_true == 2) & (y_pred_classes == 2))  # Normal
Pw = sum((y_true == 3) & (y_pred_classes == 3))  # Wheeze

# Obtener el total de muestras para cada clase
Crackle_total = sum(y_true == 0)  # Total de muestras de la clase Crackle
Both_total = sum(y_true == 1)     # Total de muestras de la clase Both
Normal_total = sum(y_true == 2)   # Total de muestras de la clase Normal
Wheeze_total = sum(y_true == 3)   # Total de muestras de la clase Wheeze

# Calcular el puntaje Se (Sensibilidad)
Se = (Pc + Pw + Pb) / (Crackle_total + Wheeze_total + Both_total)

# Calcular el puntaje Sp (Especificidad)
Sp = Pn / Normal_total

# Calcular el puntaje promedio
score = (Se + Sp) / 2

# Mostrar los resultados
print("Puntaje de Sensibilidad (Se):", Se)
print("Puntaje de Especificidad (Sp):", Sp)
print("Puntaje promedio:", score)
# Out:
# 87/87 [==============================] - 7s 63ms/step
# Accuracy: 0.5355587808417998
# Precision: 0.5364788573078706
# Recall: 0.5355587808417998
# F1 Score: 0.5358773321767331
# Puntaje de Sensibilidad (Se): 0.3695836873406967
# Puntaje de Especificidad (Sp): 0.6592780240658644
# Puntaje promedio: 0.5144308557032806

# %%
# Mostrar el informe de clasificación
class_report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        crackle       0.45      0.42      0.44       649
# crackle_wheeze       0.24      0.26      0.25       143
#         normal       0.65      0.66      0.66      1579
#         wheeze       0.31      0.32      0.31       385
#
#       accuracy                           0.54      2756
#      macro avg       0.41      0.42      0.41      2756
#   weighted avg       0.54      0.54      0.54      2756

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, class_names):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Calcular y mostrar la matriz de confusión
plot_confusion_matrix(y_true, y_pred_classes, class_names)

# %%
# Save the trained model
#model.save('./Best_Models/Tests/RN152V2_Adam_00005_Total.h5')
