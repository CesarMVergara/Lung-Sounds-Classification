# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print('GPU device found:')
    for device in physical_devices:
        print(device)
else:
    print('No GPU devices found.')
# Out:
# GPU device found:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
SEED = 42
import os
os.environ['PYTHONHASHSEED'] = str(SEED)
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, applications, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def reset_seeds():
    np.random.seed(SEED)
    tf.random.set_seed(SEED)
    random.seed(SEED)

reset_seeds()

policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)


train_loc = './OfficialSpectrogramsMelAUG/train'
test_loc = './OfficialSpectrogramsMelAUG/test'
#image_size = (224, 224)
#batch_size = 32

# Definir la normalización
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Crear los generadores de datos
train_generator = train_datagen.flow_from_directory(
    directory=train_loc,
    target_size=(224,224),
    shuffle=True,
    seed=SEED
)

test_generator = test_datagen.flow_from_directory(
    directory=test_loc,
    target_size=(224,224),
    shuffle=False,
    seed=SEED
)

# Definir funciones de generador
def train_generator_fn():
    for x_batch, y_batch in train_generator:
        yield x_batch, y_batch

def test_generator_fn():
    for x_batch, y_batch in test_generator:
        yield x_batch, y_batch

# Crear los datasets
train_dataset = tf.data.Dataset.from_generator(
    train_generator_fn,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, 224, 224, 3], [None, len(train_generator.class_indices)])
)

test_dataset = tf.data.Dataset.from_generator(
    test_generator_fn,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, 224, 224, 3], [None, len(test_generator.class_indices)])
)

train_dataset = train_dataset.repeat() \
                             .prefetch(buffer_size=tf.data.AUTOTUNE)

# Cálculo del número de pasos
validation_steps = test_generator.samples // test_generator.batch_size
if test_generator.samples % test_generator.batch_size != 0:
    validation_steps += 1 # Sumar 1 para el lote incompleto

# Aplicar el límite de pasos directamente al Dataset con .take()
test_dataset = test_dataset.take(validation_steps) \
                           .cache() \
                           .prefetch(buffer_size=tf.data.AUTOTUNE)

class_names = list(train_generator.class_indices.keys())
print("Class names:", class_names)

vgg19 = applications.VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in vgg19.layers:
    layer.trainable = False

for layer in vgg19.layers:
    # Congelar las primeras capas hasta 'block1'
    if 'block1' not in layer.name:
        layer.trainable = True
        print(f"Layer '{layer.name}' is now trainable")

x = vgg19.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.5)(x)
prediction = layers.Dense(len(class_names), activation='softmax', name='predictions')(x)

model = models.Model(inputs=vgg19.input, outputs=prediction)

model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0001),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

model.summary()
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4090, compute capability 8.9
# Found 8544 images belonging to 4 classes.
# Found 2756 images belonging to 4 classes.
# Class names: ['crackle', 'crackle_wheeze', 'normal', 'wheeze']
# Layer 'input_1' is now trainable
# Layer 'block2_conv1' is now trainable
# Layer 'block2_conv2' is now trainable
# Layer 'block2_pool' is now trainable
# Layer 'block3_conv1' is now trainable
# Layer 'block3_conv2' is now trainable
# Layer 'block3_conv3' is now trainable
# Layer 'block3_conv4' is now trainable
# Layer 'block3_pool' is now trainable
# Layer 'block4_conv1' is now trainable
# Layer 'block4_conv2' is now trainable
# Layer 'block4_conv3' is now trainable
# Layer 'block4_conv4' is now trainable
# Layer 'block4_pool' is now trainable
# Layer 'block5_conv1' is now trainable
# Layer 'block5_conv2' is now trainable
# Layer 'block5_conv3' is now trainable
# Layer 'block5_conv4' is now trainable
# Layer 'block5_pool' is now trainable
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  predictions (Dense)         (None, 4)                 4100
#
# =================================================================
# Total params: 20,553,796
# Trainable params: 20,515,076
# Non-trainable params: 38,720
# _________________________________________________________________

# %%
# Callback personalizado para monitorear dos métricas y una condición adicional
class CustomModelCheckpoint(callbacks.Callback):
    def __init__(self, filepath, monitor1='val_accuracy', monitor2='val_loss', mode1='max', mode2='min', save_best_only=True, ignore_initial_epochs=15, verbose=0, loss_threshold=3):
        super().__init__()
        self.filepath = filepath
        self.monitor1 = monitor1
        self.monitor2 = monitor2
        self.mode1 = mode1
        self.mode2 = mode2
        self.save_best_only = save_best_only
        self.ignore_initial_epochs = ignore_initial_epochs
        self.verbose = verbose
        self.loss_threshold = loss_threshold
        self.best = None  # Guardamos la mejor métrica principal
        self.best_epoch = -1

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.ignore_initial_epochs:
            return
        
        current1 = logs.get(self.monitor1)
        current2 = logs.get(self.monitor2)

        if current2 < self.loss_threshold and (self.best is None or self._compare(current1, self.best, self.mode1)):
            self.best = current1
            self.best_epoch = epoch
            if self.verbose > 0:
                print(f"\nEpoch {epoch + 1}: {self.monitor1} improved to {current1}, {self.monitor2} is {current2}, saving model to {self.filepath}")
            if self.save_best_only:
                self.model.save(self.filepath, overwrite=True)
            else:
                self.model.save(self.filepath.format(epoch=epoch, **logs))
        else:
            if self.verbose > 0:
                # La precisión no mejoró o la pérdida falló.
                if current2 >= self.loss_threshold:
                    print(f"\nEpoch {epoch + 1}: Val loss ({current2:.4f}) is >= threshold ({self.loss_threshold:.1f}). No model saved.")
                else:
                    print(f"\nEpoch {epoch + 1}: {self.monitor1} did not improve from {self.best:.4f}. Val loss is {current2:.4f}. No model saved.")
                    
    def _compare(self, current, best, mode):
        if best is None:
            return True
        if mode == 'max':
            return current > best
        else:  # mode == 'min'
            return current < best


# Callback personalizado para EarlyStopping
class CustomEarlyStopping(callbacks.EarlyStopping):
    def __init__(self, *args, ignore_initial_epochs=3, **kwargs):
        super().__init__(*args, **kwargs)
        self.ignore_initial_epochs = ignore_initial_epochs
        self.wait = 0  # To track the number of epochs since the best score was improved

    def on_epoch_end(self, epoch, logs=None):
        if epoch >= self.ignore_initial_epochs:
            super().on_epoch_end(epoch, logs)

# %%
# Ruta para guardar el modelo
checkpoint_path = './Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5'

IGNORE_INITIAL_EPOCHS=5

# Callback para guardar el mejor modelo basado en la precisión en el conjunto de validación
checkpoint_callback = CustomModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    ignore_initial_epochs=IGNORE_INITIAL_EPOCHS
)
early_acc = CustomEarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=40, verbose=1, mode='max',
    ignore_initial_epochs=IGNORE_INITIAL_EPOCHS
)
early_loss = CustomEarlyStopping(
    monitor='val_loss', min_delta=0, patience=40, verbose=1, mode='min',
    ignore_initial_epochs=IGNORE_INITIAL_EPOCHS
)

# %%
from collections import Counter

counter = Counter(train_generator.classes)                       
max_val = float(max(counter.values()))   
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}
class_weights
# Out:
# {0: 1.0, 1: 1.564657393096342, 2: 1.4721279689772175, 3: 2.0206254158349966}

# %%
# Train the model
history = model.fit(train_dataset, validation_data=test_dataset,
                    steps_per_epoch=train_generator.samples//train_generator.batch_size,
                    epochs=250, callbacks=[checkpoint_callback, early_acc, early_loss], verbose=2, class_weight=class_weights)
# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print("Validation loss:", loss)
print("Validation accuracy:", accuracy)
# Out:
# Epoch 1/250
# 267/267 - 55s - loss: 2.0002 - accuracy: 0.2637 - val_loss: 1.3873 - val_accuracy: 0.2565 - 55s/epoch - 205ms/step
# Epoch 2/250
# 267/267 - 29s - loss: 2.0166 - accuracy: 0.3043 - val_loss: 1.3631 - val_accuracy: 0.4347 - 29s/epoch - 108ms/step
# Epoch 3/250
# 267/267 - 32s - loss: 1.8880 - accuracy: 0.3670 - val_loss: 2.0182 - val_accuracy: 0.4858 - 32s/epoch - 118ms/step
# Epoch 4/250
# 267/267 - 31s - loss: 1.6403 - accuracy: 0.4882 - val_loss: 1.5459 - val_accuracy: 0.4038 - 31s/epoch - 117ms/step
# Epoch 5/250
# 267/267 - 32s - loss: 1.5301 - accuracy: 0.5310 - val_loss: 1.3326 - val_accuracy: 0.4684 - 32s/epoch - 120ms/step
# Epoch 6/250
#
# Epoch 6: val_accuracy improved to 0.4894775152206421, val_loss is 1.4031884670257568, saving model to ./Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5
# 267/267 - 32s - loss: 1.4507 - accuracy: 0.5605 - val_loss: 1.4032 - val_accuracy: 0.4895 - 32s/epoch - 121ms/step
# Epoch 7/250
#
# Epoch 7: val_accuracy did not improve from 0.4895. Val loss is 1.3728. No model saved.
# 267/267 - 32s - loss: 1.3988 - accuracy: 0.5717 - val_loss: 1.3728 - val_accuracy: 0.4815 - 32s/epoch - 120ms/step
# Epoch 8/250
#
# Epoch 8: val_accuracy did not improve from 0.4895. Val loss is 1.6193. No model saved.
# 267/267 - 32s - loss: 1.3348 - accuracy: 0.5980 - val_loss: 1.6193 - val_accuracy: 0.3980 - 32s/epoch - 120ms/step
# Epoch 9/250
#
# Epoch 9: val_accuracy did not improve from 0.4895. Val loss is 1.6959. No model saved.
# 267/267 - 32s - loss: 1.2961 - accuracy: 0.6110 - val_loss: 1.6959 - val_accuracy: 0.3875 - 32s/epoch - 119ms/step
# Epoch 10/250
#
# Epoch 10: val_accuracy improved to 0.512699544429779, val_loss is 1.6767932176589966, saving model to ./Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5
# 267/267 - 32s - loss: 1.2318 - accuracy: 0.6321 - val_loss: 1.6768 - val_accuracy: 0.5127 - 32s/epoch - 120ms/step
# Epoch 11/250
#
# Epoch 11: val_accuracy did not improve from 0.5127. Val loss is 1.8351. No model saved.
# 267/267 - 32s - loss: 1.2033 - accuracy: 0.6386 - val_loss: 1.8351 - val_accuracy: 0.4089 - 32s/epoch - 118ms/step
# Epoch 12/250
#
# Epoch 12: val_accuracy did not improve from 0.5127. Val loss is 2.0026. No model saved.
# 267/267 - 31s - loss: 1.1387 - accuracy: 0.6615 - val_loss: 2.0026 - val_accuracy: 0.4735 - 31s/epoch - 117ms/step
# Epoch 13/250
#
# Epoch 13: val_accuracy did not improve from 0.5127. Val loss is 1.7033. No model saved.
# 267/267 - 32s - loss: 1.0957 - accuracy: 0.6759 - val_loss: 1.7033 - val_accuracy: 0.4539 - 32s/epoch - 118ms/step
# Epoch 14/250
#
# Epoch 14: val_accuracy did not improve from 0.5127. Val loss is 1.4927. No model saved.
# 267/267 - 31s - loss: 1.0567 - accuracy: 0.6944 - val_loss: 1.4927 - val_accuracy: 0.4895 - 31s/epoch - 117ms/step
# Epoch 15/250
#
# Epoch 15: val_accuracy did not improve from 0.5127. Val loss is 1.8918. No model saved.
# 267/267 - 32s - loss: 1.0072 - accuracy: 0.7075 - val_loss: 1.8918 - val_accuracy: 0.4390 - 32s/epoch - 118ms/step
# Epoch 16/250
#
# Epoch 16: val_accuracy did not improve from 0.5127. Val loss is 1.8338. No model saved.
# 267/267 - 32s - loss: 0.9850 - accuracy: 0.7142 - val_loss: 1.8338 - val_accuracy: 0.5025 - 32s/epoch - 118ms/step
# Epoch 17/250
#
# Epoch 17: val_accuracy improved to 0.5156023502349854, val_loss is 1.6404945850372314, saving model to ./Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5
# 267/267 - 32s - loss: 0.9293 - accuracy: 0.7306 - val_loss: 1.6405 - val_accuracy: 0.5156 - 32s/epoch - 118ms/step
# Epoch 18/250
#
# Epoch 18: val_accuracy improved to 0.5500725507736206, val_loss is 1.631706953048706, saving model to ./Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5
# 267/267 - 32s - loss: 0.8915 - accuracy: 0.7426 - val_loss: 1.6317 - val_accuracy: 0.5501 - 32s/epoch - 120ms/step
# Epoch 19/250
#
# Epoch 19: val_accuracy did not improve from 0.5501. Val loss is 1.7171. No model saved.
# 267/267 - 32s - loss: 0.8598 - accuracy: 0.7574 - val_loss: 1.7171 - val_accuracy: 0.5403 - 32s/epoch - 119ms/step
# Epoch 20/250
#
# Epoch 20: val_accuracy did not improve from 0.5501. Val loss is 1.4625. No model saved.
# 267/267 - 32s - loss: 0.8267 - accuracy: 0.7618 - val_loss: 1.4625 - val_accuracy: 0.5225 - 32s/epoch - 119ms/step
# Epoch 21/250
#
# Epoch 21: val_accuracy did not improve from 0.5501. Val loss is 2.0783. No model saved.
# 267/267 - 32s - loss: 0.7923 - accuracy: 0.7817 - val_loss: 2.0783 - val_accuracy: 0.4434 - 32s/epoch - 119ms/step
# Epoch 22/250
#
# Epoch 22: val_accuracy did not improve from 0.5501. Val loss is 2.1334. No model saved.
# 267/267 - 33s - loss: 0.7764 - accuracy: 0.7863 - val_loss: 2.1334 - val_accuracy: 0.5033 - 33s/epoch - 122ms/step
# Epoch 23/250
#
# Epoch 23: val_accuracy did not improve from 0.5501. Val loss is 1.6264. No model saved.
# 267/267 - 30s - loss: 0.7458 - accuracy: 0.7954 - val_loss: 1.6264 - val_accuracy: 0.5446 - 30s/epoch - 113ms/step
# Epoch 24/250
#
# Epoch 24: val_accuracy did not improve from 0.5501. Val loss is 1.7733. No model saved.
# 267/267 - 32s - loss: 0.7296 - accuracy: 0.8034 - val_loss: 1.7733 - val_accuracy: 0.5312 - 32s/epoch - 120ms/step
# Epoch 25/250
#
# Epoch 25: val_accuracy did not improve from 0.5501. Val loss is 1.8295. No model saved.
# 267/267 - 32s - loss: 0.7056 - accuracy: 0.8059 - val_loss: 1.8295 - val_accuracy: 0.5287 - 32s/epoch - 119ms/step
# Epoch 26/250
#
# Epoch 26: val_accuracy did not improve from 0.5501. Val loss is 2.8315. No model saved.
# 267/267 - 32s - loss: 0.7066 - accuracy: 0.8148 - val_loss: 2.8315 - val_accuracy: 0.5036 - 32s/epoch - 118ms/step
# Epoch 27/250
#
# Epoch 27: val_accuracy did not improve from 0.5501. Val loss is 2.0244. No model saved.
# 267/267 - 32s - loss: 0.6607 - accuracy: 0.8250 - val_loss: 2.0244 - val_accuracy: 0.5083 - 32s/epoch - 119ms/step
# Epoch 28/250
#
# Epoch 28: val_accuracy did not improve from 0.5501. Val loss is 2.2459. No model saved.
# 267/267 - 31s - loss: 0.6705 - accuracy: 0.8223 - val_loss: 2.2459 - val_accuracy: 0.5497 - 31s/epoch - 118ms/step
# Epoch 29/250
#
# Epoch 29: val_accuracy did not improve from 0.5501. Val loss is 2.7863. No model saved.
# 267/267 - 32s - loss: 0.6619 - accuracy: 0.8332 - val_loss: 2.7863 - val_accuracy: 0.5218 - 32s/epoch - 118ms/step
# Epoch 30/250
#
# Epoch 30: val_accuracy did not improve from 0.5501. Val loss is 2.0476. No model saved.
# 267/267 - 31s - loss: 0.6274 - accuracy: 0.8343 - val_loss: 2.0476 - val_accuracy: 0.5207 - 31s/epoch - 117ms/step
# Epoch 31/250
#
# Epoch 31: val_accuracy did not improve from 0.5501. Val loss is 2.9275. No model saved.
# 267/267 - 31s - loss: 0.6322 - accuracy: 0.8344 - val_loss: 2.9275 - val_accuracy: 0.4089 - 31s/epoch - 118ms/step
# Epoch 32/250
#
# Epoch 32: val_accuracy did not improve from 0.5501. Val loss is 2.5032. No model saved.
# 267/267 - 32s - loss: 0.6343 - accuracy: 0.8366 - val_loss: 2.5032 - val_accuracy: 0.5269 - 32s/epoch - 120ms/step
# Epoch 33/250
#
# Epoch 33: val_accuracy did not improve from 0.5501. Val loss is 2.6657. No model saved.
# 267/267 - 32s - loss: 0.6231 - accuracy: 0.8363 - val_loss: 2.6657 - val_accuracy: 0.5080 - 32s/epoch - 121ms/step
# Epoch 34/250
#
# Epoch 34: val_accuracy did not improve from 0.5501. Val loss is 2.4882. No model saved.
# 267/267 - 32s - loss: 0.6329 - accuracy: 0.8390 - val_loss: 2.4882 - val_accuracy: 0.5087 - 32s/epoch - 120ms/step
# Epoch 35/250
#
# Epoch 35: Val loss (3.3048) is >= threshold (3.0). No model saved.
# 267/267 - 33s - loss: 0.6331 - accuracy: 0.8336 - val_loss: 3.3048 - val_accuracy: 0.5116 - 33s/epoch - 124ms/step
# Epoch 36/250
#
# Epoch 36: val_accuracy did not improve from 0.5501. Val loss is 2.0528. No model saved.
# 267/267 - 32s - loss: 0.6405 - accuracy: 0.8382 - val_loss: 2.0528 - val_accuracy: 0.5243 - 32s/epoch - 119ms/step
# Epoch 37/250
#
# Epoch 37: val_accuracy did not improve from 0.5501. Val loss is 2.0731. No model saved.
# 267/267 - 32s - loss: 0.6009 - accuracy: 0.8456 - val_loss: 2.0731 - val_accuracy: 0.5345 - 32s/epoch - 119ms/step
# Epoch 38/250
#
# Epoch 38: val_accuracy did not improve from 0.5501. Val loss is 2.3170. No model saved.
# 267/267 - 31s - loss: 0.6538 - accuracy: 0.8488 - val_loss: 2.3170 - val_accuracy: 0.5174 - 31s/epoch - 115ms/step
# Epoch 39/250
#
# Epoch 39: val_accuracy did not improve from 0.5501. Val loss is 2.5237. No model saved.
# 267/267 - 32s - loss: 0.6291 - accuracy: 0.8464 - val_loss: 2.5237 - val_accuracy: 0.4815 - 32s/epoch - 120ms/step
# Epoch 40/250
#
# Epoch 40: val_accuracy improved to 0.5580551624298096, val_loss is 2.1934926509857178, saving model to ./Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5
# 267/267 - 32s - loss: 0.5831 - accuracy: 0.8494 - val_loss: 2.1935 - val_accuracy: 0.5581 - 32s/epoch - 121ms/step
# Epoch 41/250
#
# Epoch 41: val_accuracy did not improve from 0.5581. Val loss is 2.2897. No model saved.
# 267/267 - 32s - loss: 0.5958 - accuracy: 0.8546 - val_loss: 2.2897 - val_accuracy: 0.4390 - 32s/epoch - 118ms/step
# Epoch 42/250
#
# Epoch 42: val_accuracy did not improve from 0.5581. Val loss is 2.7600. No model saved.
# 267/267 - 32s - loss: 0.5954 - accuracy: 0.8555 - val_loss: 2.7600 - val_accuracy: 0.5247 - 32s/epoch - 119ms/step
# Epoch 43/250
#
# Epoch 43: Val loss (3.1003) is >= threshold (3.0). No model saved.
# 267/267 - 32s - loss: 0.6121 - accuracy: 0.8512 - val_loss: 3.1003 - val_accuracy: 0.5392 - 32s/epoch - 118ms/step
# Epoch 44/250
#
# Epoch 44: val_accuracy did not improve from 0.5581. Val loss is 2.8152. No model saved.
# 267/267 - 32s - loss: 0.6429 - accuracy: 0.8539 - val_loss: 2.8152 - val_accuracy: 0.5185 - 32s/epoch - 119ms/step
# Epoch 45/250
#
# Epoch 45: val_accuracy did not improve from 0.5581. Val loss is 2.7469. No model saved.
# 267/267 - 32s - loss: 0.6230 - accuracy: 0.8549 - val_loss: 2.7469 - val_accuracy: 0.5323 - 32s/epoch - 119ms/step
# Epoch 46/250
#
# Epoch 46: Val loss (3.0590) is >= threshold (3.0). No model saved.
# 267/267 - 32s - loss: 0.6201 - accuracy: 0.8488 - val_loss: 3.0590 - val_accuracy: 0.4710 - 32s/epoch - 119ms/step
# Epoch 47/250
#
# Epoch 47: Val loss (5.2500) is >= threshold (3.0). No model saved.
# 267/267 - 32s - loss: 0.8017 - accuracy: 0.8601 - val_loss: 5.2500 - val_accuracy: 0.4935 - 32s/epoch - 119ms/step
# Epoch 47: early stopping
# 87/87 [==============================] - 11s 122ms/step - loss: 5.2500 - accuracy: 0.4935
# Validation loss: 5.250011444091797
# Validation accuracy: 0.4934687912464142

# %%
import matplotlib.pyplot as plt

# Plotear el accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plotear el loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# Predicciones en el conjunto de prueba
predictions = model.predict(test_generator)

# Obtener las etiquetas verdaderas del conjunto de prueba
y_true = test_generator.classes

# Convertir las predicciones en etiquetas de clase
y_pred_classes = np.argmax(predictions, axis=1)

# Calcular métricas
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')

# Mostrar las métricas
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Obtener el número total de predicciones correctas para cada clase
Pc = sum((y_true == 0) & (y_pred_classes == 0))  # Crackle
Pb = sum((y_true == 1) & (y_pred_classes == 1))  # Both
Pn = sum((y_true == 2) & (y_pred_classes == 2))  # Normal
Pw = sum((y_true == 3) & (y_pred_classes == 3))  # Wheeze

# Obtener el total de muestras para cada clase
Crackle_total = sum(y_true == 0)  # Total de muestras de la clase Crackle
Both_total = sum(y_true == 1)     # Total de muestras de la clase Both
Normal_total = sum(y_true == 2)   # Total de muestras de la clase Normal
Wheeze_total = sum(y_true == 3)   # Total de muestras de la clase Wheeze

# Calcular el puntaje Se (Sensibilidad)
Se = (Pc + Pw + Pb) / (Crackle_total + Wheeze_total + Both_total)

# Calcular el puntaje Sp (Especificidad)
Sp = Pn / Normal_total

# Calcular el puntaje promedio
score = (Se + Sp) / 2

# Mostrar los resultados
print("Puntaje de Sensibilidad (Se):", Se)
print("Puntaje de Especificidad (Sp):", Sp)
print("Puntaje promedio:", score)
# Out:
# 87/87 [==============================] - 11s 125ms/step
# Accuracy: 0.4934687953555878
# Precision: 0.5229178235445363
# Recall: 0.4934687953555878
# F1 Score: 0.5053610648617307
# Puntaje de Sensibilidad (Se): 0.35598980458793544
# Puntaje de Especificidad (Sp): 0.5959468017732742
# Puntaje promedio: 0.4759683031806048

# %%
# Mostrar el informe de clasificación
class_report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        crackle       0.38      0.35      0.37       649
# crackle_wheeze       0.15      0.27      0.19       143
#         normal       0.67      0.60      0.63      1579
#         wheeze       0.31      0.39      0.34       385
#
#       accuracy                           0.49      2756
#      macro avg       0.38      0.40      0.38      2756
#   weighted avg       0.52      0.49      0.51      2756

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, class_names):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Calcular y mostrar la matriz de confusión
plot_confusion_matrix(y_true, y_pred_classes, class_names)

# %%
# Save the trained model
#model.save('./Best_Models/Official/RMSprop/VGG19_RMSprop_0001.h5')
