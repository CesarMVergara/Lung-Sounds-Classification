# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print('GPU device found:')
    for device in physical_devices:
        print(device)
else:
    print('No GPU devices found.')
# Out:
# GPU device found:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
SEED = 42
import os
os.environ['PYTHONHASHSEED'] = str(SEED)
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, applications, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def reset_seeds():
    np.random.seed(SEED)
    tf.random.set_seed(SEED)
    random.seed(SEED)

reset_seeds()

policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)


train_loc = './OfficialSpectrogramsMelAUG/train'
test_loc = './OfficialSpectrogramsMelAUG/test'
#image_size = (224, 224)
#batch_size = 32

# Definir la normalización
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Crear los generadores de datos
train_generator = train_datagen.flow_from_directory(
    directory=train_loc,
    target_size=(224,224),
    shuffle=True,
    seed=SEED
)

test_generator = test_datagen.flow_from_directory(
    directory=test_loc,
    target_size=(224,224),
    shuffle=False,
    seed=SEED
)

# Definir funciones de generador
def train_generator_fn():
    for x_batch, y_batch in train_generator:
        yield x_batch, y_batch

def test_generator_fn():
    for x_batch, y_batch in test_generator:
        yield x_batch, y_batch

# Crear los datasets
train_dataset = tf.data.Dataset.from_generator(
    train_generator_fn,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, 224, 224, 3], [None, len(train_generator.class_indices)])
)

test_dataset = tf.data.Dataset.from_generator(
    test_generator_fn,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, 224, 224, 3], [None, len(test_generator.class_indices)])
)

train_dataset = train_dataset.repeat() \
                             .prefetch(buffer_size=tf.data.AUTOTUNE)

# Cálculo del número de pasos
validation_steps = test_generator.samples // test_generator.batch_size
if test_generator.samples % test_generator.batch_size != 0:
    validation_steps += 1 # Sumar 1 para el lote incompleto

# Aplicar el límite de pasos directamente al Dataset con .take()
test_dataset = test_dataset.take(validation_steps) \
                           .cache() \
                           .prefetch(buffer_size=tf.data.AUTOTUNE)

class_names = list(train_generator.class_indices.keys())
print("Class names:", class_names)

vgg16 = applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in vgg16.layers:
    layer.trainable = False

for layer in vgg16.layers:
    # Congelar las primeras capas hasta 'block1'
    if 'block1' not in layer.name:
        layer.trainable = True
        print(f"Layer '{layer.name}' is now trainable")

x = vgg16.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.5)(x)
prediction = layers.Dense(len(class_names), activation='softmax', name='predictions')(x)

model = models.Model(inputs=vgg16.input, outputs=prediction)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

model.summary()
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4090, compute capability 8.9
# Found 8544 images belonging to 4 classes.
# Found 2756 images belonging to 4 classes.
# Class names: ['crackle', 'crackle_wheeze', 'normal', 'wheeze']
# Layer 'input_1' is now trainable
# Layer 'block2_conv1' is now trainable
# Layer 'block2_conv2' is now trainable
# Layer 'block2_pool' is now trainable
# Layer 'block3_conv1' is now trainable
# Layer 'block3_conv2' is now trainable
# Layer 'block3_conv3' is now trainable
# Layer 'block3_pool' is now trainable
# Layer 'block4_conv1' is now trainable
# Layer 'block4_conv2' is now trainable
# Layer 'block4_conv3' is now trainable
# Layer 'block4_pool' is now trainable
# Layer 'block5_conv1' is now trainable
# Layer 'block5_conv2' is now trainable
# Layer 'block5_conv3' is now trainable
# Layer 'block5_pool' is now trainable
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  predictions (Dense)         (None, 4)                 4100
#
# =================================================================
# Total params: 15,244,100
# Trainable params: 15,205,380
# Non-trainable params: 38,720
# _________________________________________________________________

# %%
# Callback personalizado para monitorear dos métricas y una condición adicional
class CustomModelCheckpoint(callbacks.Callback):
    def __init__(self, filepath, monitor1='val_accuracy', monitor2='val_loss', mode1='max', mode2='min', save_best_only=True, ignore_initial_epochs=15, verbose=0, loss_threshold=3):
        super().__init__()
        self.filepath = filepath
        self.monitor1 = monitor1
        self.monitor2 = monitor2
        self.mode1 = mode1
        self.mode2 = mode2
        self.save_best_only = save_best_only
        self.ignore_initial_epochs = ignore_initial_epochs
        self.verbose = verbose
        self.loss_threshold = loss_threshold
        self.best = None  # Guardamos la mejor métrica principal
        self.best_epoch = -1

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.ignore_initial_epochs:
            return
        
        current1 = logs.get(self.monitor1)
        current2 = logs.get(self.monitor2)

        if current2 < self.loss_threshold and (self.best is None or self._compare(current1, self.best, self.mode1)):
            self.best = current1
            self.best_epoch = epoch
            if self.verbose > 0:
                print(f"\nEpoch {epoch + 1}: {self.monitor1} improved to {current1}, {self.monitor2} is {current2}, saving model to {self.filepath}")
            if self.save_best_only:
                self.model.save(self.filepath, overwrite=True)
            else:
                self.model.save(self.filepath.format(epoch=epoch, **logs))
        else:
            if self.verbose > 0:
                # La precisión no mejoró o la pérdida falló.
                if current2 >= self.loss_threshold:
                    print(f"\nEpoch {epoch + 1}: Val loss ({current2:.4f}) is >= threshold ({self.loss_threshold:.1f}). No model saved.")
                else:
                    print(f"\nEpoch {epoch + 1}: {self.monitor1} did not improve from {self.best:.4f}. Val loss is {current2:.4f}. No model saved.")

    def _compare(self, current, best, mode):
        if best is None:
            return True
        if mode == 'max':
            return current > best
        else:  # mode == 'min'
            return current < best


# Callback personalizado para EarlyStopping
class CustomEarlyStopping(callbacks.EarlyStopping):
    def __init__(self, *args, ignore_initial_epochs=3, **kwargs):
        super().__init__(*args, **kwargs)
        self.ignore_initial_epochs = ignore_initial_epochs
        self.wait = 0  # To track the number of epochs since the best score was improved

    def on_epoch_end(self, epoch, logs=None):
        if epoch >= self.ignore_initial_epochs:
            super().on_epoch_end(epoch, logs)

# %%
# Ruta para guardar el modelo
checkpoint_path = './Best_Models/Official/Adam/VGG16_Adam_00005.h5'

IGNORE_INITIAL_EPOCHS=5

# Callback para guardar el mejor modelo basado en la precisión en el conjunto de validación
checkpoint_callback = CustomModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    ignore_initial_epochs=IGNORE_INITIAL_EPOCHS
)
early_acc = CustomEarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=40, verbose=1, mode='max',
    ignore_initial_epochs=IGNORE_INITIAL_EPOCHS
)
early_loss = CustomEarlyStopping(
    monitor='val_loss', min_delta=0, patience=40, verbose=1, mode='min',
    ignore_initial_epochs=IGNORE_INITIAL_EPOCHS
)

# %%
from collections import Counter

counter = Counter(train_generator.classes)                       
max_val = float(max(counter.values()))   
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}
class_weights
# Out:
# {0: 1.0, 1: 1.564657393096342, 2: 1.4721279689772175, 3: 2.0206254158349966}

# %%
# Train the model
history = model.fit(train_dataset, validation_data=test_dataset,
                    steps_per_epoch=train_generator.samples//train_generator.batch_size,
                    epochs=250, callbacks=[checkpoint_callback, early_acc, early_loss], verbose=2, class_weight=class_weights)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print("Validation loss:", loss)
print("Validation accuracy:", accuracy)
# Out:
# Epoch 1/250
# 267/267 - 56s - loss: 1.9787 - accuracy: 0.2660 - val_loss: 1.3897 - val_accuracy: 0.0526 - 56s/epoch - 211ms/step
# Epoch 2/250
# 267/267 - 31s - loss: 1.9706 - accuracy: 0.2640 - val_loss: 1.3858 - val_accuracy: 0.1397 - 31s/epoch - 115ms/step
# Epoch 3/250
# 267/267 - 33s - loss: 1.9691 - accuracy: 0.3000 - val_loss: 1.4006 - val_accuracy: 0.1705 - 33s/epoch - 125ms/step
# Epoch 4/250
# 267/267 - 34s - loss: 1.9612 - accuracy: 0.2972 - val_loss: 1.5215 - val_accuracy: 0.1488 - 34s/epoch - 126ms/step
# Epoch 5/250
# 267/267 - 34s - loss: 1.9574 - accuracy: 0.3237 - val_loss: 1.3751 - val_accuracy: 0.1967 - 34s/epoch - 126ms/step
# Epoch 6/250
#
# Epoch 6: val_accuracy improved to 0.17888243496418, val_loss is 1.3780502080917358, saving model to ./Best_Models/Official/Adam/VGG16_Adam_00005.h5
# 267/267 - 34s - loss: 1.9501 - accuracy: 0.3407 - val_loss: 1.3781 - val_accuracy: 0.1789 - 34s/epoch - 127ms/step
# Epoch 7/250
#
# Epoch 7: val_accuracy improved to 0.4680696725845337, val_loss is 1.1730258464813232, saving model to ./Best_Models/Official/Adam/VGG16_Adam_00005.h5
# 267/267 - 34s - loss: 1.7042 - accuracy: 0.4336 - val_loss: 1.1730 - val_accuracy: 0.4681 - 34s/epoch - 127ms/step
# Epoch 8/250
#
# Epoch 8: val_accuracy did not improve from 0.4681. Val loss is 1.4988. No model saved.
# 267/267 - 33s - loss: 1.5148 - accuracy: 0.5210 - val_loss: 1.4988 - val_accuracy: 0.4655 - 33s/epoch - 125ms/step
# Epoch 9/250
#
# Epoch 9: val_accuracy did not improve from 0.4681. Val loss is 1.2351. No model saved.
# 267/267 - 33s - loss: 1.3714 - accuracy: 0.5728 - val_loss: 1.2351 - val_accuracy: 0.4478 - 33s/epoch - 122ms/step
# Epoch 10/250
#
# Epoch 10: val_accuracy did not improve from 0.4681. Val loss is 1.5634. No model saved.
# 267/267 - 32s - loss: 1.2846 - accuracy: 0.6052 - val_loss: 1.5634 - val_accuracy: 0.4300 - 32s/epoch - 120ms/step
# Epoch 11/250
#
# Epoch 11: val_accuracy did not improve from 0.4681. Val loss is 1.7179. No model saved.
# 267/267 - 32s - loss: 1.1978 - accuracy: 0.6251 - val_loss: 1.7179 - val_accuracy: 0.4198 - 32s/epoch - 121ms/step
# Epoch 12/250
#
# Epoch 12: val_accuracy improved to 0.5319303274154663, val_loss is 1.3770055770874023, saving model to ./Best_Models/Official/Adam/VGG16_Adam_00005.h5
# 267/267 - 32s - loss: 1.1063 - accuracy: 0.6607 - val_loss: 1.3770 - val_accuracy: 0.5319 - 32s/epoch - 122ms/step
# Epoch 13/250
#
# Epoch 13: val_accuracy did not improve from 0.5319. Val loss is 1.7000. No model saved.
# 267/267 - 33s - loss: 1.0422 - accuracy: 0.6860 - val_loss: 1.7000 - val_accuracy: 0.4234 - 33s/epoch - 122ms/step
# Epoch 14/250
#
# Epoch 14: val_accuracy did not improve from 0.5319. Val loss is 1.3751. No model saved.
# 267/267 - 32s - loss: 0.9769 - accuracy: 0.7092 - val_loss: 1.3751 - val_accuracy: 0.5232 - 32s/epoch - 121ms/step
# Epoch 15/250
#
# Epoch 15: val_accuracy improved to 0.53447026014328, val_loss is 1.4066241979599, saving model to ./Best_Models/Official/Adam/VGG16_Adam_00005.h5
# 267/267 - 33s - loss: 0.8950 - accuracy: 0.7419 - val_loss: 1.4066 - val_accuracy: 0.5345 - 33s/epoch - 125ms/step
# Epoch 16/250
#
# Epoch 16: val_accuracy improved to 0.562046468257904, val_loss is 1.367385983467102, saving model to ./Best_Models/Official/Adam/VGG16_Adam_00005.h5
# 267/267 - 33s - loss: 0.8123 - accuracy: 0.7680 - val_loss: 1.3674 - val_accuracy: 0.5620 - 33s/epoch - 125ms/step
# Epoch 17/250
#
# Epoch 17: val_accuracy did not improve from 0.5620. Val loss is 1.4686. No model saved.
# 267/267 - 33s - loss: 0.7333 - accuracy: 0.7969 - val_loss: 1.4686 - val_accuracy: 0.5243 - 33s/epoch - 122ms/step
# Epoch 18/250
#
# Epoch 18: val_accuracy did not improve from 0.5620. Val loss is 1.6205. No model saved.
# 267/267 - 33s - loss: 0.6771 - accuracy: 0.8118 - val_loss: 1.6205 - val_accuracy: 0.5258 - 33s/epoch - 123ms/step
# Epoch 19/250
#
# Epoch 19: val_accuracy did not improve from 0.5620. Val loss is 1.7474. No model saved.
# 267/267 - 33s - loss: 0.6142 - accuracy: 0.8327 - val_loss: 1.7474 - val_accuracy: 0.5185 - 33s/epoch - 124ms/step
# Epoch 20/250
#
# Epoch 20: val_accuracy did not improve from 0.5620. Val loss is 1.7459. No model saved.
# 267/267 - 33s - loss: 0.5514 - accuracy: 0.8496 - val_loss: 1.7459 - val_accuracy: 0.5334 - 33s/epoch - 123ms/step
# Epoch 21/250
#
# Epoch 21: val_accuracy did not improve from 0.5620. Val loss is 2.1112. No model saved.
# 267/267 - 33s - loss: 0.5023 - accuracy: 0.8615 - val_loss: 2.1112 - val_accuracy: 0.4739 - 33s/epoch - 122ms/step
# Epoch 22/250
#
# Epoch 22: val_accuracy did not improve from 0.5620. Val loss is 1.8930. No model saved.
# 267/267 - 33s - loss: 0.4677 - accuracy: 0.8735 - val_loss: 1.8930 - val_accuracy: 0.5243 - 33s/epoch - 122ms/step
# Epoch 23/250
#
# Epoch 23: val_accuracy did not improve from 0.5620. Val loss is 2.1144. No model saved.
# 267/267 - 33s - loss: 0.4521 - accuracy: 0.8789 - val_loss: 2.1144 - val_accuracy: 0.4935 - 33s/epoch - 122ms/step
# Epoch 24/250
#
# Epoch 24: val_accuracy did not improve from 0.5620. Val loss is 1.9526. No model saved.
# 267/267 - 33s - loss: 0.4078 - accuracy: 0.8920 - val_loss: 1.9526 - val_accuracy: 0.5443 - 33s/epoch - 123ms/step
# Epoch 25/250
#
# Epoch 25: val_accuracy did not improve from 0.5620. Val loss is 1.8202. No model saved.
# 267/267 - 32s - loss: 0.3930 - accuracy: 0.8993 - val_loss: 1.8202 - val_accuracy: 0.5483 - 32s/epoch - 121ms/step
# Epoch 26/250
#
# Epoch 26: val_accuracy did not improve from 0.5620. Val loss is 1.9752. No model saved.
# 267/267 - 33s - loss: 0.3551 - accuracy: 0.8993 - val_loss: 1.9752 - val_accuracy: 0.5080 - 33s/epoch - 122ms/step
# Epoch 27/250
#
# Epoch 27: val_accuracy did not improve from 0.5620. Val loss is 2.3870. No model saved.
# 267/267 - 32s - loss: 0.3461 - accuracy: 0.9036 - val_loss: 2.3870 - val_accuracy: 0.5279 - 32s/epoch - 122ms/step
# Epoch 28/250
#
# Epoch 28: val_accuracy did not improve from 0.5620. Val loss is 2.0366. No model saved.
# 267/267 - 32s - loss: 0.3311 - accuracy: 0.9073 - val_loss: 2.0366 - val_accuracy: 0.5399 - 32s/epoch - 121ms/step
# Epoch 29/250
#
# Epoch 29: val_accuracy did not improve from 0.5620. Val loss is 2.3093. No model saved.
# 267/267 - 33s - loss: 0.3148 - accuracy: 0.9137 - val_loss: 2.3093 - val_accuracy: 0.5152 - 33s/epoch - 122ms/step
# Epoch 30/250
#
# Epoch 30: val_accuracy did not improve from 0.5620. Val loss is 2.4434. No model saved.
# 267/267 - 33s - loss: 0.3025 - accuracy: 0.9175 - val_loss: 2.4434 - val_accuracy: 0.4757 - 33s/epoch - 124ms/step
# Epoch 31/250
#
# Epoch 31: val_accuracy did not improve from 0.5620. Val loss is 2.0198. No model saved.
# 267/267 - 33s - loss: 0.2869 - accuracy: 0.9217 - val_loss: 2.0198 - val_accuracy: 0.5058 - 33s/epoch - 124ms/step
# Epoch 32/250
#
# Epoch 32: val_accuracy did not improve from 0.5620. Val loss is 2.1257. No model saved.
# 267/267 - 33s - loss: 0.2743 - accuracy: 0.9251 - val_loss: 2.1257 - val_accuracy: 0.5454 - 33s/epoch - 123ms/step
# Epoch 33/250
#
# Epoch 33: val_accuracy did not improve from 0.5620. Val loss is 2.2731. No model saved.
# 267/267 - 33s - loss: 0.2722 - accuracy: 0.9222 - val_loss: 2.2731 - val_accuracy: 0.5167 - 33s/epoch - 124ms/step
# Epoch 34/250
#
# Epoch 34: val_accuracy did not improve from 0.5620. Val loss is 2.1951. No model saved.
# 267/267 - 33s - loss: 0.2589 - accuracy: 0.9258 - val_loss: 2.1951 - val_accuracy: 0.5377 - 33s/epoch - 124ms/step
# Epoch 35/250
#
# Epoch 35: val_accuracy did not improve from 0.5620. Val loss is 2.2794. No model saved.
# 267/267 - 33s - loss: 0.2576 - accuracy: 0.9246 - val_loss: 2.2794 - val_accuracy: 0.4688 - 33s/epoch - 122ms/step
# Epoch 36/250
#
# Epoch 36: val_accuracy did not improve from 0.5620. Val loss is 2.2688. No model saved.
# 267/267 - 33s - loss: 0.2393 - accuracy: 0.9293 - val_loss: 2.2688 - val_accuracy: 0.4924 - 33s/epoch - 122ms/step
# Epoch 37/250
#
# Epoch 37: val_accuracy did not improve from 0.5620. Val loss is 2.5348. No model saved.
# 267/267 - 33s - loss: 0.2462 - accuracy: 0.9272 - val_loss: 2.5348 - val_accuracy: 0.4648 - 33s/epoch - 122ms/step
# Epoch 38/250
#
# Epoch 38: val_accuracy did not improve from 0.5620. Val loss is 2.0763. No model saved.
# 267/267 - 33s - loss: 0.2185 - accuracy: 0.9357 - val_loss: 2.0763 - val_accuracy: 0.5573 - 33s/epoch - 122ms/step
# Epoch 39/250
#
# Epoch 39: val_accuracy did not improve from 0.5620. Val loss is 2.4462. No model saved.
# 267/267 - 33s - loss: 0.2291 - accuracy: 0.9349 - val_loss: 2.4462 - val_accuracy: 0.5044 - 33s/epoch - 122ms/step
# Epoch 40/250
#
# Epoch 40: val_accuracy did not improve from 0.5620. Val loss is 2.2159. No model saved.
# 267/267 - 33s - loss: 0.2201 - accuracy: 0.9333 - val_loss: 2.2159 - val_accuracy: 0.5131 - 33s/epoch - 123ms/step
# Epoch 41/250
#
# Epoch 41: val_accuracy did not improve from 0.5620. Val loss is 2.3529. No model saved.
# 267/267 - 33s - loss: 0.2053 - accuracy: 0.9383 - val_loss: 2.3529 - val_accuracy: 0.5301 - 33s/epoch - 122ms/step
# Epoch 42/250
#
# Epoch 42: val_accuracy did not improve from 0.5620. Val loss is 1.9259. No model saved.
# 267/267 - 32s - loss: 0.2148 - accuracy: 0.9370 - val_loss: 1.9259 - val_accuracy: 0.5552 - 32s/epoch - 121ms/step
# Epoch 43/250
#
# Epoch 43: val_accuracy did not improve from 0.5620. Val loss is 2.4985. No model saved.
# 267/267 - 32s - loss: 0.2161 - accuracy: 0.9348 - val_loss: 2.4985 - val_accuracy: 0.4982 - 32s/epoch - 120ms/step
# Epoch 44/250
#
# Epoch 44: val_accuracy did not improve from 0.5620. Val loss is 2.5711. No model saved.
# 267/267 - 33s - loss: 0.2064 - accuracy: 0.9359 - val_loss: 2.5711 - val_accuracy: 0.5218 - 33s/epoch - 124ms/step
# Epoch 45/250
#
# Epoch 45: val_accuracy did not improve from 0.5620. Val loss is 2.1214. No model saved.
# 267/267 - 32s - loss: 0.1921 - accuracy: 0.9373 - val_loss: 2.1214 - val_accuracy: 0.5530 - 32s/epoch - 122ms/step
# Epoch 46/250
#
# Epoch 46: val_accuracy did not improve from 0.5620. Val loss is 2.4780. No model saved.
# 267/267 - 33s - loss: 0.1763 - accuracy: 0.9429 - val_loss: 2.4780 - val_accuracy: 0.5229 - 33s/epoch - 122ms/step
# Epoch 47/250
#
# Epoch 47: val_accuracy did not improve from 0.5620. Val loss is 2.1963. No model saved.
# 267/267 - 33s - loss: 0.2174 - accuracy: 0.9311 - val_loss: 2.1963 - val_accuracy: 0.5167 - 33s/epoch - 125ms/step
# Epoch 47: early stopping
# 87/87 [==============================] - 12s 129ms/step - loss: 2.1963 - accuracy: 0.5167
# Validation loss: 2.196293354034424
# Validation accuracy: 0.5166908502578735

# %%
import matplotlib.pyplot as plt

# Plotear el accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plotear el loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# Predicciones en el conjunto de prueba
predictions = model.predict(test_generator)

# Obtener las etiquetas verdaderas del conjunto de prueba
y_true = test_generator.classes

# Convertir las predicciones en etiquetas de clase
y_pred_classes = np.argmax(predictions, axis=1)

# Calcular métricas
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')

# Mostrar las métricas
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Obtener el número total de predicciones correctas para cada clase
Pc = sum((y_true == 0) & (y_pred_classes == 0))  # Crackle
Pb = sum((y_true == 1) & (y_pred_classes == 1))  # Both
Pn = sum((y_true == 2) & (y_pred_classes == 2))  # Normal
Pw = sum((y_true == 3) & (y_pred_classes == 3))  # Wheeze

# Obtener el total de muestras para cada clase
Crackle_total = sum(y_true == 0)  # Total de muestras de la clase Crackle
Both_total = sum(y_true == 1)     # Total de muestras de la clase Both
Normal_total = sum(y_true == 2)   # Total de muestras de la clase Normal
Wheeze_total = sum(y_true == 3)   # Total de muestras de la clase Wheeze

# Calcular el puntaje Se (Sensibilidad)
Se = (Pc + Pw + Pb) / (Crackle_total + Wheeze_total + Both_total)

# Calcular el puntaje Sp (Especificidad)
Sp = Pn / Normal_total

# Calcular el puntaje promedio
score = (Se + Sp) / 2

# Mostrar los resultados
print("Puntaje de Sensibilidad (Se):", Se)
print("Puntaje de Especificidad (Sp):", Sp)
print("Puntaje promedio:", score)
# Out:
# 87/87 [==============================] - 11s 125ms/step
# Accuracy: 0.5166908563134979
# Precision: 0.5381805448675213
# Recall: 0.5166908563134979
# F1 Score: 0.525689282329868
# Puntaje de Sensibilidad (Se): 0.372982158028887
# Puntaje de Especificidad (Sp): 0.6238125395820139
# Puntaje promedio: 0.49839734880545045

# %%
# Mostrar el informe de clasificación
class_report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        crackle       0.42      0.40      0.41       649
# crackle_wheeze       0.14      0.18      0.16       143
#         normal       0.68      0.62      0.65      1579
#         wheeze       0.31      0.41      0.35       385
#
#       accuracy                           0.52      2756
#      macro avg       0.39      0.40      0.39      2756
#   weighted avg       0.54      0.52      0.53      2756

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, class_names):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Calcular y mostrar la matriz de confusión
plot_confusion_matrix(y_true, y_pred_classes, class_names)

# %%
# Save the trained model
#model.save('./Best_Models/Official/Adam/VGG16_Adam_00005.h5')
